# %%
# !nvidia-smi
# Out:
# Tue Aug 13 06:44:46 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.6/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ACPS PROJECT - MSDS/DATASETS/MSDS-Yv8 - TEST
# Out:
# /content/drive/MyDrive/ACPS PROJECT - MSDS/DATASETS/MSDS-Yv8 - TEST

# %%
# !ls
# Out:
# data  data_1  data_LeafDetector  data_old  data.yaml  full_data.yaml  runs  yolov8n.pt	yolov8s.pt

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= leafDetector_data.yaml epochs=50 imgsz=256 plots=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml  weights

# %%
from IPython.display import display, Image
Image(filename='runs/detect/train14/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train14/results.png', width=1200)

# %%
Image(filename='runs/detect/train14/val_batch0_pred.jpg', width=1200)

# %%
Image(filename='runs/detect/train14/val_batch0_labels.jpg', width=1200)
